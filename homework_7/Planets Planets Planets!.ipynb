# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
planets_data = sns.load_dataset('planets')
planets_data

#All the comments for the next few cells are what I tried before I looked up seaborn functions
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
#rad_vel = planets_data[planets_data['method']=='Radial Velocity']
#rad_vel

# %%
#transit = planets_data[planets_data['method']=='Transit']
#transit

# %%
#clipse = planets_data[planets_data['method']=='Eclipse Timing Variations']
#Pulsation = planets_data[planets_data['method']=='Pulsation Timing Variations']
#Astrometry = planets_data[planets_data['method']=='Astronmetry']
#transit_timing = planets_data[planets_data['method']=='Transit Timing Variations']
#Orbital = planets_data[planets_data['method']=='Orbital Brightness Modulation']
#Microlensing = planets_data[planets_data['method']=='Microlensing']
#Pulsar = planets_data[planets_data['method']=='Pulsar Timing']

# %%
#planets_data['method'].unique()
#plt.figure()
#sns.jointplot(x = rad_vel['orbital_period'],y = rad_vel['mass'],kind = 'scatter',color = 'red',marginal_kws ={'log_scale':True})
#sns.jointplot(x = transit['orbital_period'],y = transit['mass'],kind = 'scatter',color = 'blue',marginal_kws ={'log_scale':True})
#plt.show()

# %%
planets_data_new = planets_data.dropna(axis = 0)
planets_data_new.insert(3,'log orbital_period',np.log10(planets_data['orbital_period']))
planets_data_new.insert(5,'log mass',np.log10(planets_data['mass']))
g = sns.FacetGrid(planets_data_new,hue='method')
g.map(sns.scatterplot, 'log orbital_period','log mass')
g.tight_layout()
g.add_legend()
plt.show()
# Out:
# C:\Users\fchou\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Part 2
plt.figure(figsize=[20,10])
sns.barplot(planets_data_new, x="year", y="number", hue="method",errorbar=None)
plt.show()
