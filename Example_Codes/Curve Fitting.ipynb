# %%
import numpy as np
y_obs = np.array([0,15,27,13,18])
def f(x):
    return 10*x+3

# %%
x = np.array([0,5,3,1,7])
y_hat = f(x)

# %%
y_hat
# Out:
# array([ 3, 53, 33, 13, 73])

# %%
np.mean((y_obs-y_hat)**2)
# Out:
# 902.8

# %%
#Fitting
import matplotlib.pyplot as plt
import scipy.optimize as fit

# %%
m = 0.5
b = 3
sigma = 1
n = 20
xdata = np.arange(0,n)
ydata = m*xdata + b +sigma * np.random.standard_normal(size=n)

# %%
plt.figure(figsize=(8,6))
plt.scatter(xdata,ydata)
plt.show()

# %%
def f(x,m,b):
    return m*x + b

p0 = [0.3,1]
parameters, covariance_matrix = fit.curve_fit(f,xdata,ydata,p0)

# %%
parameters
# Out:
# array([0.46070699, 3.51503104])

# %%
covariance_matrix
# Out:
# array([[ 0.00116408, -0.01105874],
#        [-0.01105874,  0.14376356]])

# %%
m_error = covariance_matrix[0,0] ** 0.5
b_error = covariance_matrix[1,1] ** 0.5

# %%
m = parameters[0]
b= parameters[1]

# %%
print('m={0:1.5f} +/- {1:1.5f}'.format(m,m_error))
# Out:
# m=0.46071 +/- 0.03412

# %%
x = np.linspace(xdata.min(),xdata.max(),100)
y = f(x,m,b)
plt.figure()
plt.plot(x,y)
plt.scatter(xdata,ydata)
plt.show()
